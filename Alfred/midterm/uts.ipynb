# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Path to your GIF file
gif_path = "2-Pentagon.gif"

# Open the GIF file
capture = cv2.VideoCapture(gif_path)

ret,frame = capture.read()

plt.imshow(frame)

# %%
def haris_corner(image):


    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    gray = np.float32(gray)

    corner = cv2.cornerHarris(gray,5,3,0.04)
    # corner=cv2.cornerHarris()
    corner = cv2.dilate(corner,None)

    threshold = corner > 0.01*corner.max()

    image[threshold]= [0,255,255]

    print(len(threshold))
    plt.figure()
    plt.imshow(image, cmap='gray')
    plt.title('Corner Detection')
    plt.axis('off')

# %%
haris_corner(frame)
# Out:
# 1024

# %%
def shi_tomasi(image,qualityLevel =  0.155 ):
    # quality_level = 0.155  # Adjust this value to control the threshold

# Detect corners using the Shi-Tomasi corner detector
    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    corners = cv2.goodFeaturesToTrack(gray_image, maxCorners=100, qualityLevel=qualityLevel, minDistance=10)

# Convert corners to integers
    corners = np.int0(corners)

# Draw circles around the detected corners
    for corner in corners:
        x, y = corner.ravel()
        cv2.circle(image, (x, y), 3, (0, 0, 255), -1)

    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Image with Corners Detected')
    plt.axis('off')
    plt.show()

    # Print the total number of corners detected
    corner_count = len(corners)
    print("Total corners detected:", corner_count)

# %%
shi_tomasi(frame)
# Out:
# /tmp/ipykernel_13416/3867129692.py:9: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)
# Total corners detected: 5

# %%
shi_tomasi(frame,0.5)
# Out:
# /tmp/ipykernel_13416/3867129692.py:9: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)
# Total corners detected: 9
