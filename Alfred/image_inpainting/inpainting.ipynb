# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
import cv2
 
# Open the image.
img = cv2.imread('cat_damaged.png')
 
# Load the mask.
mask = cv2.imread('cat_mask.png', 0)
 
# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)


import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(mask,cv2.COLOR_BGR2RGB))
plt.title('Mask Image')


plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.title('Inpainted  Image')

plt.show()

# %%
img = cv2.imread('image4.png')
 
# Load the mask.
mask = cv2.imread('mask4.png', 0)
 
# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)


import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(mask,cv2.COLOR_BGR2RGB))
plt.title('Mask Image')


plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.title('Inpainted  Image')

plt.show()

# %%
img = cv2.imread('images/input_image_big.png')
 
# Load the mask.
mask = cv2.imread('images/mask_big.png', 0) 
 
# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)


import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(mask,cv2.COLOR_BGR2RGB))
plt.title('Mask Image')


plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.title('Inpainted  Image')

plt.show()

# %%
img = cv2.imread('images/input_image_noise.png')
 
# Load the mask.
mask = cv2.imread('images/mask_noise.png', 0)
 
# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)


import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(mask,cv2.COLOR_BGR2RGB))
plt.title('Mask Image')


plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.title('Inpainted  Image')

plt.show()

# %%
img = cv2.imread('image5.png')
 
# Load the mask.
mask = cv2.imread('mask5.png', 0)
 
# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)


import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(mask,cv2.COLOR_BGR2RGB))
plt.title('Mask Image')


plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.title('Inpainted  Image')

plt.show()

# %%
img = cv2.imread('image6.png')
 
# Load the mask.
mask = cv2.imread('mask6.png', 0)
 
# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)


import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(mask,cv2.COLOR_BGR2RGB))
plt.title('Mask Image')


plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.title('Inpainted  Image')

plt.show()

# %%
img = cv2.imread('image3.png')
 
# Load the mask.
mask = cv2.imread('mask3.png', 0)
 
# Inpaint.
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_NS)


import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(mask,cv2.COLOR_BGR2RGB))
plt.title('Mask Image')


plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.title('Inpainted  Image')

plt.show()
