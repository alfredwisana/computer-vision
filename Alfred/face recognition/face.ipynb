# %%
import face_recognition
import matplotlib.pyplot as plt
import cv2
from scipy import ndimage

# %%
# Load the image file
image_path = "doll.jpg"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 2 faces in the image.

# %%
# Load the image file
image_path = "monyet.jpg"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 0 faces in the image.

# %%
# Load the image file
image_path = "rika.jpg"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 1 faces in the image.

# %%
# Load the image file
image_path = "turu.jpg"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 6 faces in the image.

# %%
# Load the image file
image_path = "td2.jpg"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 46 faces in the image.

# %%
# Load the image file
image_path = "jtp1.jpg"
image = face_recognition.load_image_file(image_path)
# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 0 faces in the image.

# %%
# Load the image file
image_path = "jtp1.jpg"
image = face_recognition.load_image_file(image_path)
image = ndimage.rotate(image, angle=-90, axes=(0, 1), reshape=False)  # Rotate 45 degrees counter-clockwise
# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 2 faces in the image.

# %%
# Load the image file
image_path = "pps1.jpg"
image = face_recognition.load_image_file(image_path)
# image = ndimage.rotate(image, angle=-90, axes=(0, 1), reshape=False)  # Rotate 45 degrees counter-clockwise
# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 18 faces in the image.

# %%
# Load the image file
image_path = "meet1.png"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 15 faces in the image.

# %%
# Load the image file
image_path = "sd1.jpg"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 0 faces in the image.

# %%
# Load the image file
image_path = "bw1.png"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 2 faces in the image.

# %%
# Load the image file
image_path = "monyet2.jpg"
image = face_recognition.load_image_file(image_path)

# Find all face locations in the image
face_locations = face_recognition.face_locations(image)
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} faces in the image.".format(len(face_locations)))

# Display the image with face bounding boxes
for face_location in face_locations:
    top, right, bottom, left = face_location
    cv2.rectangle(image, (left, top), (right, bottom), (0, 0, 255), 2)



plt.imshow(image)
plt.show()
# Out:
# Found 0 faces in the image.

# %%
known_image = face_recognition.load_image_file("prabowo1.jpg")
unknown_image = face_recognition.load_image_file("prabowo2.jpg")

prabowo_encoding = face_recognition.face_encodings(known_image)[0]
unknown_encoding = face_recognition.face_encodings(unknown_image)[0]

results = face_recognition.compare_faces([biden_encoding], unknown_encoding)
print(results)

face_locations = face_recognition.face_locations(known_image)
face_locations = face_recognition.face_locations(unknown_image)

plt.figure(figsize=(10,6))

plt.subplot(1,2,1)
plt.imshow(known_image)

plt.subplot(1,2,2)
plt.imshow(unknown_image)

plt.show()
# Out:
# [True]
